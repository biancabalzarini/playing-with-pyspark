# %% [markdown]
# ## Analytics con DataFrames sobre datos semi estructurados

# %%
import urllib

with urllib.request.urlopen('https://github.com/juanpampliega/datasets/raw/master/http_access_200304.log.gz') as response:
  gzipcontent = response.read()

with open("/tmp/test_http_access_log.gz", 'wb') as f:
  f.write(gzipcontent)

dbutils.fs.cp("file:/tmp/test_http_access_log.gz", "/tmp/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
access_logs = sc.textFile("dbfs:/tmp/test_http_access_log.gz")
access_logs.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [&#39;129.118.191.108 - - [05/Apr/2003:00:17:25 -0800] &#34;GET /archive/cat/humor/index.shtml HTTP/1.1&#34; 200 28310 &#34;http://www.google.com/search?hl=en&amp;ie=UTF-8&amp;oe=UTF-8&amp;q=animated+gifs+John+Mayer&#34; &#34;Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Hotbar 4.2.8.0)&#34;&#39;,
#  &#39;62.31.206.207 - - [06/Apr/2003:13:24:39 -0700] &#34;GET /archive/2002/08/index.shtml HTTP/1.1&#34; 200 25401 &#34;http://www.ask.co.uk/metasearch.asp?aj_product=IndexSearch&amp;MetaEngine=Teoma&amp;EngineOrdinal=2&amp;ItemOrdinal=1&amp;m=9&amp;AdServerCode=&amp;MetaURL=http%3A%2F%2Fwww%2Ewaxy%2Eorg%2Farchive%2F2002%2F08%2Findex%2Eshtml__score_1.00__&amp;MetaTopic=Waxy%2Eorg%3A+August+2002&amp;ask=Dial%2Ba%2Bnumber%2Band%2Bplay%2Ba%2Bsong&amp;LogId=FC26096A1C25D840AD99E2D96C93615A&amp;origin=0&amp;qsource=1&amp;qcategory=TUNE&amp;aj_is=no&amp;rf=&amp;x=false&amp;uk=false&#34; &#34;Mozilla/4.0 (compatible; MSIE 5.5; Windows 98; Win 9x 4.90)&#34;&#39;,
#  &#39;205.188.209.43 - - [09/Apr/2003:20:51:30 -0700] &#34;GET /archive/2002/04/22/birthday.shtml HTTP/1.0&#34; 200 12364 &#34;http://www.google.com/search?hl=en&amp;lr=&amp;ie=ISO-8859-1&amp;q=Julie+M.+Fidler&#34; &#34;Mozilla/4.0 (compatible; MSIE 6.0; AOL 8.0; Windows NT 5.1; .NET CLR 1.0.3705)&#34;&#39;,
#  &#39;24.186.80.132 - - [09/Apr/2003:23:45:49 -0700] &#34;GET /archive/2003/03/26/hiding_s.shtml HTTP/1.1&#34; 200 17019 &#34;http://search.yahoo.com/bin/search?p=%22Jun+Hirax%22&#34; &#34;Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Win 9x 4.90; YComp 5.0.2.4; .NET CLR 1.0.3705)&#34;&#39;,
#  &#39;69.10.137.199 - - [10/Apr/2003:00:00:00 -0700] &#34;GET /watch-info HTTP/1.0&#34; 200 75 &#34;-&#34; &#34;-&#34;&#39;]</div>

# %%
import re
import json

def parse_access_log_line(line):
  
  format_pat= re.compile( 
      r"(?P<host>[\d\.]+)\s" 
      r"(?P<identity>\S*)\s" 
      r"(?P<user>\S*)\s"
      r"\[(?P<time>.*?)\]\s"
      r'"(?P<request>.*?)"\s'
      r"(?P<status>\d+)\s"
      r"(?P<bytes>\S*)\s"
      r'"(?P<referer>.*?)"\s' # [SIC]
      r'"(?P<user_agent>.*?)"\s*' 
  )

  match = format_pat.match(line)
  return json.dumps(match.groupdict())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
access_logs = sc.textFile("dbfs:/tmp/test_http_access_log.gz")
access_logs_json = access_logs.map(parse_access_log_line)

access_logs_json.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>
# [&apos;{&quot;referer&quot;: &quot;http://www.google.com/search?hl=en&amp;ie=UTF-8&amp;oe=UTF-8&amp;q=animated+gifs+John+Mayer&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Hotbar 4.2.8.0)&quot;, &quot;host&quot;: &quot;129.118.191.108&quot;, &quot;bytes&quot;: &quot;28310&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /archive/cat/humor/index.shtml HTTP/1.1&quot;, &quot;time&quot;: &quot;05/Apr/2003:00:17:25 -0800&quot;}&apos;,
#  &apos;{&quot;referer&quot;: &quot;http://www.ask.co.uk/metasearch.asp?aj_product=IndexSearch&amp;MetaEngine=Teoma&amp;EngineOrdinal=2&amp;ItemOrdinal=1&amp;m=9&amp;AdServerCode=&amp;MetaURL=http%3A%2F%2Fwww%2Ewaxy%2Eorg%2Farchive%2F2002%2F08%2Findex%2Eshtml__score_1.00__&amp;MetaTopic=Waxy%2Eorg%3A+August+2002&amp;ask=Dial%2Ba%2Bnumber%2Band%2Bplay%2Ba%2Bsong&amp;LogId=FC26096A1C25D840AD99E2D96C93615A&amp;origin=0&amp;qsource=1&amp;qcategory=TUNE&amp;aj_is=no&amp;rf=&amp;x=false&amp;uk=false&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;Mozilla/4.0 (compatible; MSIE 5.5; Windows 98; Win 9x 4.90)&quot;, &quot;host&quot;: &quot;62.31.206.207&quot;, &quot;bytes&quot;: &quot;25401&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /archive/2002/08/index.shtml HTTP/1.1&quot;, &quot;time&quot;: &quot;06/Apr/2003:13:24:39 -0700&quot;}&apos;,
#  &apos;{&quot;referer&quot;: &quot;http://www.google.com/search?hl=en&amp;lr=&amp;ie=ISO-8859-1&amp;q=Julie+M.+Fidler&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;Mozilla/4.0 (compatible; MSIE 6.0; AOL 8.0; Windows NT 5.1; .NET CLR 1.0.3705)&quot;, &quot;host&quot;: &quot;205.188.209.43&quot;, &quot;bytes&quot;: &quot;12364&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /archive/2002/04/22/birthday.shtml HTTP/1.0&quot;, &quot;time&quot;: &quot;09/Apr/2003:20:51:30 -0700&quot;}&apos;,
#  &apos;{&quot;referer&quot;: &quot;http://search.yahoo.com/bin/search?p=%22Jun+Hirax%22&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Win 9x 4.90; YComp 5.0.2.4; .NET CLR 1.0.3705)&quot;, &quot;host&quot;: &quot;24.186.80.132&quot;, &quot;bytes&quot;: &quot;17019&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /archive/2003/03/26/hiding_s.shtml HTTP/1.1&quot;, &quot;time&quot;: &quot;09/Apr/2003:23:45:49 -0700&quot;}&apos;,
#  &apos;{&quot;referer&quot;: &quot;-&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;-&quot;, &quot;host&quot;: &quot;69.10.137.199&quot;, &quot;bytes&quot;: &quot;75&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /watch-info HTTP/1.0&quot;, &quot;time&quot;: &quot;10/Apr/2003:00:00:00 -0700&quot;}&apos;]
# </div>

# %%
logs = spark.read.json(access_logs_json)

logs.printSchema()
logs.show()

logs.createOrReplaceTempView("logs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- bytes: string (nullable = true)
# -- host: string (nullable = true)
# -- identity: string (nullable = true)
# -- referer: string (nullable = true)
# -- request: string (nullable = true)
# -- status: string (nullable = true)
# -- time: string (nullable = true)
# -- user: string (nullable = true)
# -- user_agent: string (nullable = true)
#
# +-----+---------------+--------+--------------------+--------------------+------+--------------------+----+--------------------+
# bytes|           host|identity|             referer|             request|status|                time|user|          user_agent|
# +-----+---------------+--------+--------------------+--------------------+------+--------------------+----+--------------------+
# 28310|129.118.191.108|       -|http://www.google...|GET /archive/cat/...|   200|05/Apr/2003:00:17...|   -|Mozilla/4.0 (comp...|
# 25401|  62.31.206.207|       -|http://www.ask.co...|GET /archive/2002...|   200|06/Apr/2003:13:24...|   -|Mozilla/4.0 (comp...|
# 12364| 205.188.209.43|       -|http://www.google...|GET /archive/2002...|   200|09/Apr/2003:20:51...|   -|Mozilla/4.0 (comp...|
# 17019|  24.186.80.132|       -|http://search.yah...|GET /archive/2003...|   200|09/Apr/2003:23:45...|   -|Mozilla/4.0 (comp...|
#    75|  69.10.137.199|       -|                   -|GET /watch-info H...|   200|10/Apr/2003:00:00...|   -|                   -|
# 26553|    63.200.51.4|       -|http://www.kottke...|GET /archive/2003...|   200|10/Apr/2003:00:00...|   -|Mozilla/4.0 (comp...|
#   282|207.175.242.183|       -|                   -|GET /favicon.ico ...|   404|10/Apr/2003:00:00...|   -|Mozilla/5.0 (Wind...|
#  9455|  65.214.36.115|       -|                   -|GET /archive/cat/...|   200|10/Apr/2003:00:00...|   -|Mozilla/2.0 (comp...|
#     -| 208.61.124.145|       -|                   -|GET /index.rdf HT...|   304|10/Apr/2003:00:00...|   -|  Syndirella/0.91pre|
# 16971|   145.145.6.14|       -|http://www.volkom...|GET /archive/2003...|   200|10/Apr/2003:00:00...|   -|Mozilla/4.0 (comp...|
#     -|  68.32.124.154|       -|                   -|GET /index.rdf HT...|   304|10/Apr/2003:00:01...|   -|SharpReader/0.9.0...|
# 26553|  64.229.168.29|       -|                   -|GET /archive/2003...|   200|10/Apr/2003:00:01...|   -|Mozilla/5.0 Galeo...|
# 37164|   66.196.72.28|       -|                   -|GET /archive/2002...|   200|10/Apr/2003:00:02...|   -|Mozilla/5.0 (Slur...|
# 34477|  63.60.212.127|       -|http://www.google...|GET /archive/cat/...|   200|10/Apr/2003:00:03...|   -|Mozilla/4.0 (comp...|
# 50527|  65.214.36.115|       -|                   -|GET /archive/cat/...|   200|10/Apr/2003:00:03...|   -|Mozilla/2.0 (comp...|
# 68895|  24.130.248.43|       -|                   -|      GET / HTTP/1.0|   200|10/Apr/2003:00:04...|   -|Mozilla/3.0 (comp...|
# 69048|   213.67.2.245|       -|http://www.altavi...|      GET / HTTP/1.1|   200|10/Apr/2003:00:04...|   -|Mozilla/4.0 (comp...|
# 34477|  63.60.212.127|       -|http://www.waxy.o...|GET /archive/cat/...|   200|10/Apr/2003:00:04...|   -|Mozilla/4.0 (comp...|
#   142|  66.157.201.71|       -|                   -|GET /projects/eba...|   200|10/Apr/2003:00:04...|   -|Mozilla/4.0 (comp...|
# 69048|   62.238.73.85|       -|http://images.goo...|      GET / HTTP/1.1|   200|10/Apr/2003:00:04...|   -|Mozilla/4.0 (comp...|
# +-----+---------------+--------+--------------------+--------------------+------+--------------------+----+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# %sql
SELECT
  time,
  unix_timestamp(substring(time,0,11), 'dd/MMM/yyyy'),
  from_unixtime(unix_timestamp(substring(time,0,11), 'dd/MMM/yyyy'),"yyyy-MM-dd")
FROM logs
limit 7
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>time</th><th>unix_timestamp(substring(time, 0, 11), dd/MMM/yyyy)</th><th>from_unixtime(unix_timestamp(substring(time, 0, 11), dd/MMM/yyyy), yyyy-MM-dd)</th></tr></thead><tbody><tr><td>05/Apr/2003:00:17:25 -0800</td><td>1049500800</td><td>2003-04-05</td></tr><tr><td>06/Apr/2003:13:24:39 -0700</td><td>1049587200</td><td>2003-04-06</td></tr><tr><td>09/Apr/2003:20:51:30 -0700</td><td>1049846400</td><td>2003-04-09</td></tr><tr><td>09/Apr/2003:23:45:49 -0700</td><td>1049846400</td><td>2003-04-09</td></tr><tr><td>10/Apr/2003:00:00:00 -0700</td><td>1049932800</td><td>2003-04-10</td></tr><tr><td>10/Apr/2003:00:00:05 -0700</td><td>1049932800</td><td>2003-04-10</td></tr><tr><td>10/Apr/2003:00:00:07 -0700</td><td>1049932800</td><td>2003-04-10</td></tr></tbody></table></div>

# %%
sql = sqlContext.sql("""
SELECT 
  from_unixtime(unix_timestamp(substring(time,0,11), 'dd/MMM/yyyy'),"yyyy-MM-dd") as day,
  status,
  count(1) as mount
FROM logs
GROUP BY from_unixtime(unix_timestamp(substring(time,0,11), 'dd/MMM/yyyy'),"yyyy-MM-dd"), status
ORDER BY 1, 2
""")
sql.show()

display(sql)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
36</td></tr><tr><td>2003-04-17</td><td>301</td><td>8</td></tr><tr><td>2003-04-17</td><td>302</td><td>171</td></tr><tr><td>2003-04-17</td><td>304</td><td>567</td></tr><tr><td>2003-04-17</td><td>401</td><td>2</td></tr><tr><td>2003-04-17</td><td>403</td><td>30</td></tr><tr><td>2003-04-17</td><td>404</td><td>339</td></tr><tr><td>2003-04-18</td><td>200</td><td>3364</td></tr><tr><td>2003-04-18</td><td>206</td><td>14</td></tr><tr><td>2003-04-18</td><td>301</td><td>4</td></tr><tr><td>2003-04-18</td><td>302</td><td>150</td></tr><tr><td>2003-04-18</td><td>304</td><td>607</td></tr><tr><td>2003-04-18</td><td>403</td><td>11</td></tr><tr><td>2003-04-18</td><td>404</td><td>132</td></tr><tr><td>2003-04-19</td><td>200</td><td>2782</td></tr><tr><td>2003-04-19 ...

# %%
print(logs)
statuses = logs.groupBy("status").count().orderBy("count")
display(statuses)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>status</th><th>count</th></tr></thead><tbody><tr><td>400</td><td>1</td></tr><tr><td>405</td><td>4</td></tr><tr><td>401</td><td>17</td></tr><tr><td>301</td><td>385</td></tr><tr><td>206</td><td>1518</td></tr><tr><td>403</td><td>1913</td></tr><tr><td>404</td><td>4202</td></tr><tr><td>304</td><td>14030</td></tr><tr><td>302</td><td>16471</td></tr><tr><td>200</td><td>83331</td></tr></tbody></table></div>

# %%
files = ['ipligence-lite.csv', 'http_access_200304.log.gz', 'http_access_200306.log.gz', 'http_access_200307.log.gz']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def download_file(file):
  with urllib.request.urlopen('https://github.com/juanpampliega/datasets/raw/master/{f}'.format(f=file)) as response:
    gzipcontent = response.read()

  with open('/dbfs/tmp/{f}'.format(f=file), 'wb') as f:
    f.write(gzipcontent)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for f in files:
  download_file(f)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
logs2 = sc.textFile("dbfs:/tmp/http_access_2003*")
records = logs2.map(parse_access_log_line)

records.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>
# [&apos;{&quot;referer&quot;: &quot;http://www.google.com/search?hl=en&amp;ie=UTF-8&amp;oe=UTF-8&amp;q=animated+gifs+John+Mayer&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Hotbar 4.2.8.0)&quot;, &quot;host&quot;: &quot;129.118.191.108&quot;, &quot;bytes&quot;: &quot;28310&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /archive/cat/humor/index.shtml HTTP/1.1&quot;, &quot;time&quot;: &quot;05/Apr/2003:00:17:25 -0800&quot;}&apos;,
#  &apos;{&quot;referer&quot;: &quot;http://www.ask.co.uk/metasearch.asp?aj_product=IndexSearch&amp;MetaEngine=Teoma&amp;EngineOrdinal=2&amp;ItemOrdinal=1&amp;m=9&amp;AdServerCode=&amp;MetaURL=http%3A%2F%2Fwww%2Ewaxy%2Eorg%2Farchive%2F2002%2F08%2Findex%2Eshtml__score_1.00__&amp;MetaTopic=Waxy%2Eorg%3A+August+2002&amp;ask=Dial%2Ba%2Bnumber%2Band%2Bplay%2Ba%2Bsong&amp;LogId=FC26096A1C25D840AD99E2D96C93615A&amp;origin=0&amp;qsource=1&amp;qcategory=TUNE&amp;aj_is=no&amp;rf=&amp;x=false&amp;uk=false&quot;, &quot;identity&quot;: &quot;-&quot;, &quot;user&quot;: &quot;-&quot;, &quot;user_agent&quot;: &quot;Mozilla/4.0 (compatible; MSIE 5.5; Windows 98; Win 9x 4.90)&quot;, &quot;host&quot;: &quot;62.31.206.207&quot;, &quot;bytes&quot;: &quot;25401&quot;, &quot;status&quot;: &quot;200&quot;, &quot;request&quot;: &quot;GET /archive/2002/08/index.shtml HTTP/1.1&quot;, &quot;time&quot;: &quot;06/Apr/2003:13:24:39 -0700&quot;}&apos;]
# </div>

# %%
all_logs = spark.read.json(records)

all_logs.printSchema()

all_logs.createOrReplaceTempView("all_logs")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- bytes: string (nullable = true)
# -- host: string (nullable = true)
# -- identity: string (nullable = true)
# -- referer: string (nullable = true)
# -- request: string (nullable = true)
# -- status: string (nullable = true)
# -- time: string (nullable = true)
# -- user: string (nullable = true)
# -- user_agent: string (nullable = true)
#
# </div>

# %%
geo_ip = sqlContext.read.format('csv').options(header='true', inferSchema='true').load('dbfs:/tmp/ipligence-lite.csv')

geo_ip.createOrReplaceTempView("geo_ips")

display(geo_ip)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>from_ip</th><th>to_ip</th><th>country_iso</th><th>country</th><th>region</th><th>region_name</th></tr></thead><tbody><tr><td>0</td><td>16777215</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16777216</td><td>16777471</td><td>AU</td><td>AUSTRALIA</td><td>OC</td><td>OCEANIA</td></tr><tr><td>16777472</td><td>16778239</td><td>CN</td><td>CHINA</td><td>AS</td><td>ASIA</td></tr><tr><td>16778240</td><td>16779263</td><td>AU</td><td>AUSTRALIA</td><td>OC</td><td>OCEANIA</td></tr><tr><td>16779264</td><td>16781311</td><td>CN</td><td>CHINA</td><td>AS</td><td>ASIA</td></tr><tr><td>16781312</td><td>16785407</td><td>JP</td><td>JAPAN</td><td>AS</td><td>ASIA</td></tr><tr><td>16785408</td><td>16793599</td><td>CN</td><td>CHINA</td><td>AS</td><td>ASIA</td></tr><tr><td>16793600</td><td>16809983</td><td>JP</td><td>JAPAN</td><td>AS</td><td>ASIA</td></tr><tr><td>16809984</td><td>16842751</td><td>TH</td><td>THAILAND</td><td>AS</td><td>ASIA</td></tr><tr><td>16842752</td><td>16843007</td><td>CN</td><td>CHINA</td><td>AS</td><td>ASIA</td></tr><tr><td>16843008</td><td>16843263</td><td>AU</td><td>AUSTRALIA</td><td>OC</td><td>OCEANIA</td></tr><tr><td>16843264</td><td>16859135</td><td>CN</td><td>CHINA</td><td>AS</td><td>ASIA</td></tr><tr><td>16859136</td><td>16875519</td><td>JP</td><td>JAPAN</td><td>AS</td><td>ASIA</td></tr><tr><td>16875520</td><td>16908287</td><td>TH</td><td>THAILAND</td><td>AS</td><td>ASIA</td></tr><tr><td>16908288</td><td>16909055</td><td>CN</td><td>CHINA</td><td>AS</td><td>ASIA</td></tr><tr><td>16909056</td><td>16909311</td><td>AU</td><td>AUSTRALIA</td><td>OC</td><td>OCEANIA</td></tr><tr><td>16909312</td><td>16941055</td><td>CN</td><td>CHINA</td><td>AS</
178</td><td>US</td></tr><tr><td>66.8.137.244</td><td>US</td></tr><tr><td>203.97.2.243</td><td>NZ</td></tr><tr><td>69.10.137.199</td><td>CA</td></tr><tr><td>61.199.231.250</td><td>JP</td></tr><tr><td>65.214.36.115</td><td>US</td></tr><tr><td>24.186.80.132</td><td>US</td></tr><tr><td>64.220.165.160</td><td>US</td></tr><tr><td>213.66.51.167</td><td>SE</td></tr><tr><td>194.229.146.2</td><td>NL</td></tr><tr><td>24.130.248.43</td><td>US</td></tr><tr><td>66.67.113.34</td><td>US</td></tr><tr><td>69.10.137.199</td><td>CA</td></tr><tr><td>65.214.36.115</td><td>US</td></tr><tr><td>24.186.80.132</td><td>US</td></tr><tr><td>68.63.110.67</td><td>US</td></tr><tr><td>24.186.80.132</td><td>US</td></tr><tr><td>62.65.237.59</td><td>EE</td></tr><tr><td>155.91.6.72</td><td>US</td></tr><tr><td>207.44.200.37</td><td>US</td></tr><tr><td>213.115.209.94</td><td>SE</td></tr><tr><td>213.115.209.94</td><td>SE</td></tr><tr><td>68.32.124.154</td><td>US</td></tr><tr><td>69.10.137.199</td><td>CA</td></tr><tr><td>202.155.87.50</td><td>ID</td></tr><tr><td>213.115.209.94</td><td>SE</td></tr><tr><td>213.115.209.94</td><td>SE</td></tr><tr><td>65.214.36.115</td><td>US</td></tr><tr><td>213.115.209.94</td><td>SE</td></tr><tr><td>203.51.232.246</td><td>AU</td></tr><tr><td>208.61.124.145</td><td>US</td></tr><tr><td>195.3.113.21</td><td>AT</td></tr><tr><td>216.249.95.47</td><td>US</td></tr><tr><td>195.85. ...

# %%
# %sql 
SELECT country_iso, COUNT(1) AS count 
FROM tbl_ip_country
GROUP BY country_iso
ORDER BY count DESC
LIMIT 8
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_iso</th><th>count</th></tr></thead><tbody><tr><td>US</td><td>58</td></tr><tr><td>NL</td><td>11</td></tr><tr><td>CA</td><td>10</td></tr><tr><td>SE</td><td>10</td></tr><tr><td>GB</td><td>2</td></tr><tr><td>AU</td><td>2</td></tr><tr><td>IT</td><td>1</td></tr><tr><td>SA</td><td>1</td></tr></tbody></table></div>

# %%
# https://en.wikipedia.org/wiki/ISO_3166-1_alpha-3

# %%
# %sql 
SELECT 
 CASE WHEN country_iso = 'US' THEN 'USA'
      WHEN country_iso = 'NL' THEN 'NLD'
      WHEN country_iso = 'CA' THEN 'CAN'
      WHEN country_iso = 'SE' THEN 'SRB'
      WHEN country_iso = 'GB' THEN 'GBR'
      WHEN country_iso = 'AU' THEN 'AUS'
      WHEN country_iso = 'IT' THEN 'ITA'
      WHEN country_iso = 'SA' THEN 'ZAF'
      ELSE NULL END as country_iso, 
COUNT(1) AS count 
FROM tbl_ip_country
GROUP BY country_iso
ORDER BY count DESC
LIMIT 8
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_iso</th><th>count</th></tr></thead><tbody><tr><td>USA</td><td>58</td></tr><tr><td>NLD</td><td>11</td></tr><tr><td>CAN</td><td>10</td></tr><tr><td>SRB</td><td>10</td></tr><tr><td>GBR</td><td>2</td></tr><tr><td>AUS</td><td>2</td></tr><tr><td>ITA</td><td>1</td></tr><tr><td>ZAF</td><td>1</td></tr></tbody></table></div>
